# %%
import os 
import numpy as np
import pandas as pd

# %%
os.chdir("E:\\PYTHON\\04-Pandas-Exercises")
os.getcwd()
# Out:
# 'E:\\PYTHON\\04-Pandas-Exercises'

# %%
pokemon = pd.read_csv("Pokemon.csv")

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
type(pokemon)
# Out:
# pandas.core.frame.DataFrame

# %%
type(pokemon['Name'])
# Out:
# pandas.core.series.Series

# %%
type(pokemon['Name'].values)
# Out:
# numpy.ndarray

# %%
pokemon['Name'][0]
# Out:
# 'Bulbasaur'

# %%
type(pokemon['Name'].values[0])
# Out:
# str

# %%
pokemon['Name'].head()
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
len(pokemon)
# Out:
# 800

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# Total         800 non-null int64
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
pokemon.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
pokemon.sum()
# Out:
# #                                                        290251
# Name          BulbasaurIvysaurVenusaurVenusaurMega VenusaurC...
# Type 1        GrassGrassGrassGrassFireFireFireFireFireWaterW...
# Total                                                    348082
# HP                                                        55407
# Attack                                                    63201
# Defense                                                   59074
# Sp. Atk                                                   58256
# Sp. Def                                                   57522
# Speed                                                     54622
# Generation                                                 2659
# Legendary                                                    65
# dtype: object

# %%
pokemon.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
pokemon['Legendary'].sum()
# Out:
# 65

# %%
legendarypokeon = pokemon['Legendary'].sum()

# %%
pokemon[pokemon['Name']=='Pikachu']
# Out:
#      #     Name    Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 30  25  Pikachu  Electric    NaN    320  35      55       40       50
#
#     Sp. Def  Speed  Generation  Legendary
# 30       50     90           1      False

# %%
pokemon.loc[:,'Name'].isin(['Pikachu','Bulbasaur'])
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 770    False
# 771    False
# 772    False
# 773    False
# 774    False
# 775    False
# 776    False
# 777    False
# 778    False
# 779    False
# 780    False
# 781    False
# 782    False
# 783    False
# 784    False
# 785    False
# 786    False
# 787    False
# 788    False
# 789    False
# 790    False
# 791    False
# 792    False
# 793    False
# 794    False
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Name, Length: 800, dtype: bool

# %%
pokemon[pokemon.loc[:,'Name'].isin(['Pikachu','Bulbasaur'])]
# Out:
#      #       Name    Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0    1  Bulbasaur     Grass  Poison    318  45      49       49       65
# 30  25    Pikachu  Electric     NaN    320  35      55       40       50
#
#     Sp. Def  Speed  Generation  Legendary
# 0        65     45           1      False
# 30       50     90           1      False

# %%
pokemon[pokemon.loc[:,'Type 1'].isin(['Grass','Electric'])]
# Out:
#        #                      Name    Type 1    Type 2  Total   HP  Attack  \
# 0      1                 Bulbasaur     Grass    Poison    318   45      49
# 1      2                   Ivysaur     Grass    Poison    405   60      62
# 2      3                  Venusaur     Grass    Poison    525   80      82
# 3      3     VenusaurMega Venusaur     Grass    Poison    625   80     100
# 30    25                   Pikachu  Electric       NaN    320   35      55
# 31    26                    Raichu  Electric       NaN    485   60      90
# 48    43                    Oddish     Grass    Poison    320   45      50
# 49    44                     Gloom     Grass    Poison    395   60      65
# 50    45                 Vileplume     Grass    Poison    490   75      80
# 75    69                Bellsprout     Grass    Poison    300   50      75
# 76    70                Weepinbell     Grass    Poison    390   65      90
# ...

# %%
pokemon.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
pokemon.rows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-71798bcbb85c> in <module>()
# ----> 1 pokemon.rows
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
#pokemon = pokemon.rename(columns{'#':'Num'})
pokemon = pokemon.rename(columns={'#':'Number'})

# %%
pokemon.head()
pokemon.columns
# Out:
# Index(['Number', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack',
#        'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#Common Pokemon ; Pokemon who is not Legendary
commonpoke = pokemon[pokemon['Legendary']==False]
commonpoke['Legendary'].sum()
# Out:
# 0

# %%
# pokemon who are not mega in their name 
nonmegapoke = pokemon[~pokemon['Name'].str.contains('Mega')]

# %%
len(nonmegapoke)
# Out:
# 751

# %%
#check how many pokemon are there for every number
checkpoke = pokemon['Number'].groupby(pokemon['Number']).count().sort_values(ascending=False)
checkpoke
# Out:
# Number
# 479    6
# 386    4
# 711    4
# 710    4
# 150    3
# 6      3
# 413    3
# 646    3
# 303    2
# 302    2
# 648    2
# 65     2
# 555    2
# 487    2
# 308    2
# 254    2
# 306    2
# 310    2
# 492    2
# 214    2
# 384    2
# 383    2
# 382    2
# 647    2
# 641    2
# 645    2
# 94     2
# 115    2
# 445    2
# 257    2
#       ..
# 455    1
# 454    1
# 453    1
# 452    1
# 451    1
# 450    1
# 449    1
# 447    1
# 467    1
# 468    1
# 469    1
# 470    1
# 490    1
# 489    1
# 488    1
# 486    1
# 485    1
# 484    1
# 483    1
# 482    1
# 481    1
# 480    1
# 478    1
# 477    1
# 476    1
# 474    1
# 473    1
# 472    1
# 471    1
# 1      1
# Name: Number, Length: 721, dtype: int64

# %%
# consider same name as duplicates ; kepe first and drop others
noduppoke = pokemon.drop_duplicates('Number', keep='first',inplace = False)

# %%
len( noduppoke['Number'].unique())
# Out:
# 721

# %%
len( pokemon['Number'].unique())
# Out:
# 721

# %%
# Which pokemon type is the strongest and which the weakest on average? (according to total stats)

strongestavg = noduppoke[['Type 1','Total']].groupby(noduppoke['Type 1']).mean().sort_values(by='Total',ascending=False)
strongestavg
# Out:
#                Total
# Type 1
# Dragon    501.958333
# Steel     464.909091
# Flying    453.333333
# Fire      443.021277
# Psychic   442.489362
# Rock      437.804878
# Dark      434.750000
# Ice       427.086957
# Ghost     423.652174
# Ground    421.000000
# Electric  420.694444
# Water     417.200000
# Fairy     413.176471
# Grass     409.560606
# Fighting  404.360000
# Poison    399.142857
# Normal    392.161290
# Bug       365.126984

# %%
test = noduppoke[['Type 1','Total']].groupby(noduppoke['Type 1'])
test

# %%
strongmax = noduppoke[['Type 1','Total','Name']].sort_values(by='Total', ascending=False).groupby('Type 1')
strongmax

# %%
top5_poke = noduppoke[['Name', 'Total']].sort_values(by='Total', ascending=False)[0:5]
top5_poke
# Out:
#                       Name  Total
# 552                 Arceus    720
# 707                 Zekrom    680
# 544  GiratinaAltered Forme    680
# 270                  Ho-oh    680
# 269                  Lugia    680

# %%
generationpoke = noduppoke[['Generation','Total']].groupby(noduppoke['Total']).mean().sort_values(by='Total',ascending=False)
# Out:
# C:\Users\Anany\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'Total' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   """Entry point for launching an IPython kernel.

# %%
generationpoke
# Out:
#        Generation  Total
# Total
# 720      4.000000  720.0
# 680      3.818182  680.0
# 670      3.250000  670.0
# 660      5.000000  660.0
# 600      3.961538  600.0
# 580      3.333333  580.0
# 567      5.000000  567.0
# 555      1.000000  555.0
# 552      6.000000  552.0
# 550      5.000000  550.0
# 545      4.000000  545.0
# 540      2.750000  540.0
# 535      3.666667  535.0
# 534      3.250000  534.0
# 531      6.000000  531.0
# 530      3.500000  530.0
# 528      5.000000  528.0
# 525      2.812500  525.0
# 523      4.000000  523.0
# 521      6.000000  521.0
# 520      3.500000  520.0
# 519      5.000000  519.0
# 518      3.500000  518.0
# 515      3.250000  515.0
# 514      6.000000  514.0
# 510      3.666667  510.0
# 509      5.000000  509.0
# 508      5.000000  508.0
# 507      6.000000  507.0
# 505      2.142857  505.0
# ...           ...    ...
# 270      2.333333  270.0
# 269      3.000000  269.0
# 266      3.000000  266.0
# 265      1.500000  265.0
# ...
